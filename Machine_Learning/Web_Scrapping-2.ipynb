# %% [markdown]
# #### pip install bs4

# %% [markdown]
# #### pip install requests

# %% [markdown]
# #####  pip install pandas

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
url="https://www.flipkart.com/search?q=asus+Gaming+laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.rating%255B%255D%3D4%25E2%2598%2585%2B%2526%2Babove"

# %%
response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
html=BeautifulSoup(response.text)
html
# Out:
# <!DOCTYPE html>
# ...

# %%
Name=html.select("._4rR01T")
Name
# Out:
# [<div class="_4rR01T">ASUS TUF Gaming F15 (2022) Core i7 12th Gen - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA G...</div>,
#  <div class="_4rR01T">ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce G...</div>,
#  <div class="_4rR01T">ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce G...</div>,
#  <div class="_4rR01T">ASUS ROG Strix G15 (2022) Ryzen 7 Octa Core AMD R7-6800H - (16 GB/1 TB SSD/Windows 11 Home/4 GB Graphi...</div>,
#  <div class="_4rR01T">ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce G...</div>,
#  <div class="_4rR01T">ASUS ROG Strix G15 (2022) Ryzen 7 Octa Core AMD R7-6800H - (16 GB/512 GB SSD/Windows 11 Home/4 GB Grap...</div>,
#  <div class="_4rR01T">ASUS ROG Strix G15 Ryzen 9 Octa Core AMD R9-5900HX - (16 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/N...</div>,
# ...

# %%
Rating=html.select("._3LWZlK")
Rating
# Out:
# [<div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.9<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
# ...

# %%
Price=html.select("._1_WHN1")
Price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹1,00,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹58,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹52,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹89,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹55,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹86,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,04,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹94,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹87,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹55,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,64,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹67,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,12,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,39,491</div>,
#  <div class="_30jeq3 _1_WHN1">₹79,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹2,79,000</div>,
#  <div class="_30jeq3 _1_WHN1">₹58,500</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,19,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹2,33,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹87,390</div>,
# ...

# %%
Processor=html.select(".rgWa7D:nth-child(1)")
Processor
# Out:
# [<li class="rgWa7D">Intel Core i7 Processor (12th Gen)</li>,
#  <li class="rgWa7D">Intel Core i5 Processor (10th Gen)</li>,
#  <li class="rgWa7D">Intel Core i5 Processor (10th Gen)</li>,
#  <li class="rgWa7D">AMD Ryzen 7 Octa Core Processor</li>,
#  <li class="rgWa7D">Intel Core i5 Processor (10th Gen)</li>,
#  <li class="rgWa7D">AMD Ryzen 7 Octa Core Processor</li>,
#  <li class="rgWa7D">AMD Ryzen 9 Octa Core Processor</li>,
#  <li class="rgWa7D">Intel Core i5 Processor (12th Gen)</li>,
#  <li class="rgWa7D">AMD Ryzen 7 Octa Core Processor</li>,
#  <li class="rgWa7D">Intel Core i5 Processor (10th Gen)</li>,
#  <li class="rgWa7D">Intel Core i7 Processor (12th Gen)</li>,
#  <li class="rgWa7D">Intel Core i5 Processor (10th Gen)</li>,
#  <li class="rgWa7D">AMD Ryzen 7 Octa Core Processor</li>,
#  <li class="rgWa7D">AMD Ryzen 9 Octa Core Processor</li>,
#  <li class="rgWa7D">AMD Ryzen 7 Octa Core Processor</li>,
#  <li class="rgWa7D">Intel Core i9 Processor (12th Gen)</li>,
# ...

# %%
Ram=html.select(".rgWa7D:nth-child(2)")
Ram
# Out:
# [<li class="rgWa7D">16 GB DDR5 RAM</li>,
#  <li class="rgWa7D">8 GB DDR4 RAM</li>,
#  <li class="rgWa7D">8 GB DDR4 RAM</li>,
#  <li class="rgWa7D">16 GB DDR5 RAM</li>,
#  <li class="rgWa7D">8 GB DDR4 RAM</li>,
#  <li class="rgWa7D">16 GB DDR5 RAM</li>,
#  <li class="rgWa7D">16 GB DDR4 RAM</li>,
#  <li class="rgWa7D">16 GB DDR5 RAM</li>,
#  <li class="rgWa7D">8 GB DDR4 RAM</li>,
#  <li class="rgWa7D">8 GB DDR4 RAM</li>,
#  <li class="rgWa7D">16 GB DDR5 RAM</li>,
#  <li class="rgWa7D">8 GB DDR4 RAM</li>,
#  <li class="rgWa7D">16 GB DDR5 RAM</li>,
#  <li class="rgWa7D">16 GB DDR4 RAM</li>,
#  <li class="rgWa7D">16 GB DDR4 RAM</li>,
#  <li class="rgWa7D">32 GB DDR5 RAM</li>,
#  <li class="rgWa7D">8 GB DDR4 RAM</li>,
#  <li class="rgWa7D">16 GB DDR4 RAM</li>,
#  <li class="rgWa7D">32 GB DDR5 RAM</li>,
#  <li class="rgWa7D">8 GB DDR4 RAM</li>,
#  <li class="rgWa7D">8 GB DDR4 RAM</li>,
#  <li class="rgWa7D">16 GB DDR5 RAM</li>,
#  <li class="rgWa7D">16 GB DDR5 RAM</li>,
# ...

# %%
Display=html.select(".rgWa7D:nth-child(5)")
Display
# Out:
# [<li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 Inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 Inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 Inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">43.94 cm (17.3 Inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 Inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">40.64 cm (16 Inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">43.94 cm (17.3 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
#  <li class="rgWa7D">39.62 cm (15.6 inch) Display</li>,
# ...

# %%
Storage=html.select(".rgWa7D:nth-child(4)")
Storage
# Out:
# [<li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">1 TB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">1 TB SSD</li>,
#  <li class="rgWa7D">1 TB SSD</li>,
#  <li class="rgWa7D">1 TB SSD</li>,
#  <li class="rgWa7D">1 TB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">1 TB SSD</li>,
#  <li class="rgWa7D">1 TB SSD</li>,
#  <li class="rgWa7D">1 TB SSD</li>,
#  <li class="rgWa7D">1 TB SSD</li>,
#  <li class="rgWa7D">1 TB HDD|256 GB SSD</li>,
#  <li class="rgWa7D">1 TB SSD</li>,
#  <li class="rgWa7D">1 TB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>,
#  <li class="rgWa7D">512 GB SSD</li>]

# %%
Details=pd.DataFrame(Name,columns=["Gaming Laptop Name"])
Details["Processor"]=Processor
Details["Ram"]=Ram
Details["Display"]=Display
Details["Storage"]=Storage
Details["Rating"]=Rating
Details["Price"]=Price

Details
# Out:
#                                    Gaming Laptop Name  \
# 0   ASUS TUF Gaming F15 (2022) Core i7 12th Gen - ...
# 1   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...
# 2   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...
# 3   ASUS ROG Strix G15 (2022) Ryzen 7 Octa Core AM...
# 4   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...
# 5   ASUS ROG Strix G15 (2022) Ryzen 7 Octa Core AM...
# 6   ASUS ROG Strix G15 Ryzen 9 Octa Core AMD R9-59...
# 7   ASUS TUF Gaming F17 (2022) with 90Whr Battery ...
# 8   ASUS ROG Strix G15 Ryzen 7 Octa Core AMD R7-48...
# 9   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...
# 10  ASUS ROG Zephyrus M16 (2022) with 90Whr Batter...
# 11  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/1...
# 12  ASUS ROG Strix G15 (2022) with 90Whr Battery R...
# 13  ASUS ROG Strix G15 Advantage Edition Ryzen 9 O...
# 14  ASUS TUF Gaming A17 Ryzen 7 Octa Core AMD R7-4...
# 15  ASUS ROG Strix SCAR 15 (2022) Core i9 12th Gen...
# ...

# %%
Details.to_csv("C:/Users/Admin/CSE_ML/G_laptops Details.csv")

# %%
a=pd.read_csv("C:/Users/Admin/CSE_ML/G_laptops Details.csv")
a
# Out:
#     Unnamed: 0                                 Gaming Laptop Name  \
# 0            0  ASUS TUF Gaming F15 (2022) Core i7 12th Gen - ...
# 1            1  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...
# 2            2  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...
# 3            3  ASUS ROG Strix G15 (2022) Ryzen 7 Octa Core AM...
# 4            4  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...
# 5            5  ASUS ROG Strix G15 (2022) Ryzen 7 Octa Core AM...
# 6            6  ASUS ROG Strix G15 Ryzen 9 Octa Core AMD R9-59...
# 7            7  ASUS TUF Gaming F17 (2022) with 90Whr Battery ...
# 8            8  ASUS ROG Strix G15 Ryzen 7 Octa Core AMD R7-48...
# 9            9  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...
# 10          10  ASUS ROG Zephyrus M16 (2022) with 90Whr Batter...
# 11          11  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/1...
# 12          12  ASUS ROG Strix G15 (2022) with 90Whr Battery R...
# ...

# %%
f1=a["Ram"]
f1
# Out:
# 0     <li class="rgWa7D">16 GB DDR5 RAM</li>
# 1      <li class="rgWa7D">8 GB DDR4 RAM</li>
# 2      <li class="rgWa7D">8 GB DDR4 RAM</li>
# 3     <li class="rgWa7D">16 GB DDR5 RAM</li>
# 4      <li class="rgWa7D">8 GB DDR4 RAM</li>
# 5     <li class="rgWa7D">16 GB DDR5 RAM</li>
# 6     <li class="rgWa7D">16 GB DDR4 RAM</li>
# 7     <li class="rgWa7D">16 GB DDR5 RAM</li>
# 8      <li class="rgWa7D">8 GB DDR4 RAM</li>
# 9      <li class="rgWa7D">8 GB DDR4 RAM</li>
# 10    <li class="rgWa7D">16 GB DDR5 RAM</li>
# 11     <li class="rgWa7D">8 GB DDR4 RAM</li>
# 12    <li class="rgWa7D">16 GB DDR5 RAM</li>
# 13    <li class="rgWa7D">16 GB DDR4 RAM</li>
# 14    <li class="rgWa7D">16 GB DDR4 RAM</li>
# 15    <li class="rgWa7D">32 GB DDR5 RAM</li>
# 16     <li class="rgWa7D">8 GB DDR4 RAM</li>
# 17    <li class="rgWa7D">16 GB DDR4 RAM</li>
# 18    <li class="rgWa7D">32 GB DDR5 RAM</li>
# 19     <li class="rgWa7D">8 GB DDR4 RAM</li>
# 20     <li class="rgWa7D">8 GB DDR4 RAM</li>
# ...

# %%
changes=f1.str.strip(' <li class="rgWa7D">,</li>').astype(str)

# %%
changes
# Out:
# 0     16 GB DDR5 RAM
# 1      8 GB DDR4 RAM
# 2      8 GB DDR4 RAM
# 3     16 GB DDR5 RAM
# 4      8 GB DDR4 RAM
# 5     16 GB DDR5 RAM
# 6     16 GB DDR4 RAM
# 7     16 GB DDR5 RAM
# 8      8 GB DDR4 RAM
# 9      8 GB DDR4 RAM
# 10    16 GB DDR5 RAM
# 11     8 GB DDR4 RAM
# 12    16 GB DDR5 RAM
# 13    16 GB DDR4 RAM
# 14    16 GB DDR4 RAM
# 15    32 GB DDR5 RAM
# 16     8 GB DDR4 RAM
# 17    16 GB DDR4 RAM
# 18    32 GB DDR5 RAM
# 19     8 GB DDR4 RAM
# 20     8 GB DDR4 RAM
# 21    16 GB DDR5 RAM
# 22    16 GB DDR5 RAM
# 23    16 GB DDR4 RAM
# Name: Ram, dtype: object
